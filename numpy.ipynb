# %% [markdown]
# <a href="https://colab.research.google.com/github/qazakhi515/ai_foundation/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy

# %%
import numpy as np
arr = np.array([1, 3, 5, 6])
print("array:", arr)
# Out:
# array: [1 3 5 6]

# %%
import numpy as np
arr = np.array([1, 3, 5, 6])
print("array:", arr)
arr.shape
# Out:
# array: [1 3 5 6]
# (4,)

# %%
arr2 = np.array([[2,1,4,5], [2,4,5,7]])
print ('numpy_array2:', arr2)
arr2.shape
# Out:
# numpy_array2: [[2 1 4 5]
#  [2 4 5 7]]
# (2, 4)

# %%
#reshape
a = np.array ([1, 2, 5, 6, 5, 6, 2, 3])
b = a.reshape(2, 4)
print ('shaped_array:', b)
# Out:
# shaped_array: [[1 2 5 6]
#  [5 6 2 3]]

# %%
a1 = np.array([[1, 3, 5, 1], [2, 1, 5, 2], [2, 5, 4, 5]])
print ('flatten:', a.flatten())
# Out:
# flatten: [1 2 5 6 5 6 2 3]

# %%
a = np.array([[1, 2], [3, 4]])
b = np.array([[2, 0], [1, 2]])
print("dot:", a.dot(b))
# Out:
# dot: [[ 4  4]
#  [10  8]]

# %%
# random.rand
a = np.random.rand(1, 4)
print("random", a)
# Out:
# random [[0.2005935  0.62781662 0.07206474 0.4629093 ]]

# %%
#T transpose
a = np.array ([[1, 2], [3, 5]])
b = np.array ([[2, 0], [1, 4]])
print("transpose:", a.T)
print("transpose:", b.T)
# Out:
# transpose: [[1 3]
#  [2 5]]
# transpose: [[2 1]
#  [0 4]]
